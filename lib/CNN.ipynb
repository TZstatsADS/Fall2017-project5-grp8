# %% [markdown]
# ## CNN
#
# ### project goals:
#
# 1. read data -- Done
# 2. prepossing pictures -- Done
# 3. model structure
# 4. generate features
#
# python2

# %% [markdown]
# ### Initialization

# %%
import glob
import os
import cv2 
#can be installed by running "!pip install opencv-python"
#in current .ipynb
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
import time
import pandas as pd
from sklearn.utils import shuffle
from datetime import timedelta
import tempfile
import math
import random
#Adding Seed so that random initialization is consistent
from numpy.random import seed
seed(1)
from tensorflow import set_random_seed
set_random_seed(2)
import transfer_learning

# %%
num_classes = 120
image_size = 128
validation_size = 0.1
num_channels = 3
batch_size = 512
NUM_SAME_PIC = 3
learning_rate = 1e-4
#train_path = "../images/training_set/train/"
#train_class_path = "../data/training_set/label_train.csv"
training_images, testing_images, label_maps = transfer_learning.create_image_lists(
    '../data/images', testing_percentage=10, max_number_images=120)
# Out:
# INFO:tensorflow:Looking for images in 'n02085620-Chihuahua'
# WARNING:tensorflow:WARNING: Folder n02085620-Chihuahua has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02085782-Japanese_spaniel'
# WARNING:tensorflow:WARNING: Folder n02085782-Japanese_spaniel has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02085936-Maltese_dog'
# WARNING:tensorflow:WARNING: Folder n02085936-Maltese_dog has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02086079-Pekinese'
# WARNING:tensorflow:WARNING: Folder n02086079-Pekinese has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02086240-Shih-Tzu'
# WARNING:tensorflow:WARNING: Folder n02086240-Shih-Tzu has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02086646-Blenheim_spaniel'
# WARNING:tensorflow:WARNING: Folder n02086646-Blenheim_spaniel has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02086910-papillon'
# WARNING:tensorflow:WARNING: Folder n02086910-papillon has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02087046-toy_terrier'
# WARNING:tensorflow:WARNING: Folder n02087046-toy_terrier has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02087394-Rhodesian_ridgeback'
# WARNING:tensorflow:WARNING: Folder n02087394-Rhodesian_ridgeback has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02088094-Afghan_hound'
# WARNING:tensorflow:WARNING: Folder n02088094-Afghan_hound has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02088238-basset'
# WARNING:tensorflow:WARNING: Folder n02088238-basset has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02088364-beagle'
# WARNING:tensorflow:WARNING: Folder n02088364-beagle has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02088466-bloodhound'
# WARNING:tensorflow:WARNING: Folder n02088466-bloodhound has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02088632-bluetick'
# WARNING:tensorflow:WARNING: Folder n02088632-bluetick has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02089078-black-and-tan_coonhound'
# WARNING:tensorflow:WARNING: Folder n02089078-black-and-tan_coonhound has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02089867-Walker_hound'
# WARNING:tensorflow:WARNING: Folder n02089867-Walker_hound has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02089973-English_foxhound'
# WARNING:tensorflow:WARNING: Folder n02089973-English_foxhound has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02090379-redbone'
# WARNING:tensorflow:WARNING: Folder n02090379-redbone has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02090622-borzoi'
# WARNING:tensorflow:WARNING: Folder n02090622-borzoi has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02090721-Irish_wolfhound'
# WARNING:tensorflow:WARNING: Folder n02090721-Irish_wolfhound has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02091032-Italian_greyhound'
# WARNING:tensorflow:WARNING: Folder n02091032-Italian_greyhound has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02091134-whippet'
# WARNING:tensorflow:WARNING: Folder n02091134-whippet has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02091244-Ibizan_hound'
# WARNING:tensorflow:WARNING: Folder n02091244-Ibizan_hound has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02091467-Norwegian_elkhound'
# WARNING:tensorflow:WARNING: Folder n02091467-Norwegian_elkhound has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02091635-otterhound'
# WARNING:tensorflow:WARNING: Folder n02091635-otterhound has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02091831-Saluki'
# WARNING:tensorflow:WARNING: Folder n02091831-Saluki has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02092002-Scottish_deerhound'
# WARNING:tensorflow:WARNING: Folder n02092002-Scottish_deerhound has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02092339-Weimaraner'
# WARNING:tensorflow:WARNING: Folder n02092339-Weimaraner has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02093256-Staffordshire_bullterrier'
# WARNING:tensorflow:WARNING: Folder n02093256-Staffordshire_bullterrier has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02093428-American_Staffordshire_terrier'
# WARNING:tensorflow:WARNING: Folder n02093428-American_Staffordshire_terrier has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02093647-Bedlington_terrier'
# WARNING:tensorflow:WARNING: Folder n02093647-Bedlington_terrier has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02093754-Border_terrier'
# WARNING:tensorflow:WARNING: Folder n02093754-Border_terrier has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02093859-Kerry_blue_terrier'
# WARNING:tensorflow:WARNING: Folder n02093859-Kerry_blue_terrier has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02093991-Irish_terrier'
# WARNING:tensorflow:WARNING: Folder n02093991-Irish_terrier has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02094114-Norfolk_terrier'
# WARNING:tensorflow:WARNING: Folder n02094114-Norfolk_terrier has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02094258-Norwich_terrier'
# WARNING:tensorflow:WARNING: Folder n02094258-Norwich_terrier has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02094433-Yorkshire_terrier'
# WARNING:tensorflow:WARNING: Folder n02094433-Yorkshire_terrier has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02095314-wire-haired_fox_terrier'
# WARNING:tensorflow:WARNING: Folder n02095314-wire-haired_fox_terrier has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02095570-Lakeland_terrier'
# WARNING:tensorflow:WARNING: Folder n02095570-Lakeland_terrier has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02095889-Sealyham_terrier'
# WARNING:tensorflow:WARNING: Folder n02095889-Sealyham_terrier has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02096051-Airedale'
# WARNING:tensorflow:WARNING: Folder n02096051-Airedale has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02096177-cairn'
# WARNING:tensorflow:WARNING: Folder n02096177-cairn has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02096294-Australian_terrier'
# WARNING:tensorflow:WARNING: Folder n02096294-Australian_terrier has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02096437-Dandie_Dinmont'
# WARNING:tensorflow:WARNING: Folder n02096437-Dandie_Dinmont has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02096585-Boston_bull'
# WARNING:tensorflow:WARNING: Folder n02096585-Boston_bull has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02097047-miniature_schnauzer'
# WARNING:tensorflow:WARNING: Folder n02097047-miniature_schnauzer has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02097130-giant_schnauzer'
# WARNING:tensorflow:WARNING: Folder n02097130-giant_schnauzer has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02097209-standard_schnauzer'
# WARNING:tensorflow:WARNING: Folder n02097209-standard_schnauzer has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02097298-Scotch_terrier'
# WARNING:tensorflow:WARNING: Folder n02097298-Scotch_terrier has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02097474-Tibetan_terrier'
# WARNING:tensorflow:WARNING: Folder n02097474-Tibetan_terrier has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02097658-silky_terrier'
# WARNING:tensorflow:WARNING: Folder n02097658-silky_terrier has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02098105-soft-coated_wheaten_terrier'
# WARNING:tensorflow:WARNING: Folder n02098105-soft-coated_wheaten_terrier has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02098286-West_Highland_white_terrier'
# WARNING:tensorflow:WARNING: Folder n02098286-West_Highland_white_terrier has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02098413-Lhasa'
# WARNING:tensorflow:WARNING: Folder n02098413-Lhasa has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02099267-flat-coated_retriever'
# WARNING:tensorflow:WARNING: Folder n02099267-flat-coated_retriever has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02099429-curly-coated_retriever'
# WARNING:tensorflow:WARNING: Folder n02099429-curly-coated_retriever has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02099601-golden_retriever'
# WARNING:tensorflow:WARNING: Folder n02099601-golden_retriever has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02099712-Labrador_retriever'
# WARNING:tensorflow:WARNING: Folder n02099712-Labrador_retriever has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02099849-Chesapeake_Bay_retriever'
# WARNING:tensorflow:WARNING: Folder n02099849-Chesapeake_Bay_retriever has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02100236-German_short-haired_pointer'
# WARNING:tensorflow:WARNING: Folder n02100236-German_short-haired_pointer has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02100583-vizsla'
# WARNING:tensorflow:WARNING: Folder n02100583-vizsla has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02100735-English_setter'
# WARNING:tensorflow:WARNING: Folder n02100735-English_setter has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02100877-Irish_setter'
# WARNING:tensorflow:WARNING: Folder n02100877-Irish_setter has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02101006-Gordon_setter'
# WARNING:tensorflow:WARNING: Folder n02101006-Gordon_setter has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02101388-Brittany_spaniel'
# WARNING:tensorflow:WARNING: Folder n02101388-Brittany_spaniel has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02101556-clumber'
# WARNING:tensorflow:WARNING: Folder n02101556-clumber has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02102040-English_springer'
# WARNING:tensorflow:WARNING: Folder n02102040-English_springer has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02102177-Welsh_springer_spaniel'
# WARNING:tensorflow:WARNING: Folder n02102177-Welsh_springer_spaniel has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02102318-cocker_spaniel'
# WARNING:tensorflow:WARNING: Folder n02102318-cocker_spaniel has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02102480-Sussex_spaniel'
# WARNING:tensorflow:WARNING: Folder n02102480-Sussex_spaniel has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02102973-Irish_water_spaniel'
# WARNING:tensorflow:WARNING: Folder n02102973-Irish_water_spaniel has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02104029-kuvasz'
# WARNING:tensorflow:WARNING: Folder n02104029-kuvasz has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02104365-schipperke'
# WARNING:tensorflow:WARNING: Folder n02104365-schipperke has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02105056-groenendael'
# WARNING:tensorflow:WARNING: Folder n02105056-groenendael has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02105162-malinois'
# WARNING:tensorflow:WARNING: Folder n02105162-malinois has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02105251-briard'
# WARNING:tensorflow:WARNING: Folder n02105251-briard has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02105412-kelpie'
# WARNING:tensorflow:WARNING: Folder n02105412-kelpie has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02105505-komondor'
# WARNING:tensorflow:WARNING: Folder n02105505-komondor has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02105641-Old_English_sheepdog'
# WARNING:tensorflow:WARNING: Folder n02105641-Old_English_sheepdog has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02105855-Shetland_sheepdog'
# WARNING:tensorflow:WARNING: Folder n02105855-Shetland_sheepdog has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02106030-collie'
# WARNING:tensorflow:WARNING: Folder n02106030-collie has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02106166-Border_collie'
# WARNING:tensorflow:WARNING: Folder n02106166-Border_collie has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02106382-Bouvier_des_Flandres'
# WARNING:tensorflow:WARNING: Folder n02106382-Bouvier_des_Flandres has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02106550-Rottweiler'
# WARNING:tensorflow:WARNING: Folder n02106550-Rottweiler has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02106662-German_shepherd'
# WARNING:tensorflow:WARNING: Folder n02106662-German_shepherd has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02107142-Doberman'
# WARNING:tensorflow:WARNING: Folder n02107142-Doberman has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02107312-miniature_pinscher'
# WARNING:tensorflow:WARNING: Folder n02107312-miniature_pinscher has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02107574-Greater_Swiss_Mountain_dog'
# WARNING:tensorflow:WARNING: Folder n02107574-Greater_Swiss_Mountain_dog has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02107683-Bernese_mountain_dog'
# WARNING:tensorflow:WARNING: Folder n02107683-Bernese_mountain_dog has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02107908-Appenzeller'
# WARNING:tensorflow:WARNING: Folder n02107908-Appenzeller has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02108000-EntleBucher'
# WARNING:tensorflow:WARNING: Folder n02108000-EntleBucher has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02108089-boxer'
# WARNING:tensorflow:WARNING: Folder n02108089-boxer has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02108422-bull_mastiff'
# WARNING:tensorflow:WARNING: Folder n02108422-bull_mastiff has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02108551-Tibetan_mastiff'
# WARNING:tensorflow:WARNING: Folder n02108551-Tibetan_mastiff has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02108915-French_bulldog'
# WARNING:tensorflow:WARNING: Folder n02108915-French_bulldog has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02109047-Great_Dane'
# WARNING:tensorflow:WARNING: Folder n02109047-Great_Dane has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02109525-Saint_Bernard'
# WARNING:tensorflow:WARNING: Folder n02109525-Saint_Bernard has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02109961-Eskimo_dog'
# WARNING:tensorflow:WARNING: Folder n02109961-Eskimo_dog has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02110063-malamute'
# WARNING:tensorflow:WARNING: Folder n02110063-malamute has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02110185-Siberian_husky'
# WARNING:tensorflow:WARNING: Folder n02110185-Siberian_husky has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02110627-affenpinscher'
# WARNING:tensorflow:WARNING: Folder n02110627-affenpinscher has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02110806-basenji'
# WARNING:tensorflow:WARNING: Folder n02110806-basenji has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02110958-pug'
# WARNING:tensorflow:WARNING: Folder n02110958-pug has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02111129-Leonberg'
# WARNING:tensorflow:WARNING: Folder n02111129-Leonberg has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02111277-Newfoundland'
# WARNING:tensorflow:WARNING: Folder n02111277-Newfoundland has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02111500-Great_Pyrenees'
# WARNING:tensorflow:WARNING: Folder n02111500-Great_Pyrenees has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02111889-Samoyed'
# WARNING:tensorflow:WARNING: Folder n02111889-Samoyed has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02112018-Pomeranian'
# WARNING:tensorflow:WARNING: Folder n02112018-Pomeranian has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02112137-chow'
# WARNING:tensorflow:WARNING: Folder n02112137-chow has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02112350-keeshond'
# WARNING:tensorflow:WARNING: Folder n02112350-keeshond has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02112706-Brabancon_griffon'
# WARNING:tensorflow:WARNING: Folder n02112706-Brabancon_griffon has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02113023-Pembroke'
# WARNING:tensorflow:WARNING: Folder n02113023-Pembroke has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02113186-Cardigan'
# WARNING:tensorflow:WARNING: Folder n02113186-Cardigan has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02113624-toy_poodle'
# WARNING:tensorflow:WARNING: Folder n02113624-toy_poodle has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02113712-miniature_poodle'
# WARNING:tensorflow:WARNING: Folder n02113712-miniature_poodle has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02113799-standard_poodle'
# WARNING:tensorflow:WARNING: Folder n02113799-standard_poodle has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02113978-Mexican_hairless'
# WARNING:tensorflow:WARNING: Folder n02113978-Mexican_hairless has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02115641-dingo'
# WARNING:tensorflow:WARNING: Folder n02115641-dingo has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02115913-dhole'
# WARNING:tensorflow:WARNING: Folder n02115913-dhole has more than 120 images. Some images will never be selected.
# INFO:tensorflow:Looking for images in 'n02116738-African_hunting_dog'
# WARNING:tensorflow:WARNING: Folder n02116738-African_hunting_dog has more than 120 images. Some images will never be selected.

# %%
trainings = pd.DataFrame(training_images)
trainings.columns = ['labelss','pics']

# %% [markdown]
# ### reading pictures and classes

# %%
class DataSet(object):

    def __init__(self, images, labels, cls):
        self._num_examples = images.shape[0]

        self._images = images
        self._labels = labels
        self._cls = cls
        self._epochs_done = 0
        self._index_in_epoch = 0

    @property
    def images(self):
        return self._images
    
    @property
    def labels(self):
        return self._labels
    
    @property
    def cls(self):
        return self._cls

    @property
    def num_examples(self):
        return self._num_examples

    @property
    def epochs_done(self):
        return self._epochs_done

    def next_batch(self, batch_size):
        """Return the next `batch_size` examples from this data set."""
        start = self._index_in_epoch
        self._index_in_epoch += batch_size

        if self._index_in_epoch > self._num_examples:
            # After each epoch we update this
            self._epochs_done += 1
            start = 0
            self._index_in_epoch = batch_size
            assert batch_size <= self._num_examples
        end = self._index_in_epoch

        return self._images[start:end], self._labels[start:end], self._cls[start:end]

# %%
# images including all the pictures
def read_train_sets(train_path, image_size, validation_size):
#train_path = trainings

    class DataSets(object):
        pass
    data_sets = DataSets()

    start_time = time.time()

    #==== reading pictures =====
    files = train_path.pics#[train_path[f][1] for f in np.arange(length(train_path))]
    images = []
    for fl in files:
        image = cv2.imread(fl)
        image = cv2.resize(image, (image_size, image_size),0,0, cv2.INTER_LINEAR)
        image = image.astype(np.float32)
        image = np.multiply(image, 1.0 / 255.0)
        images.append(image)

        #flip
        image_flip = cv2.flip(image,1)
        images.append(image_flip)

        #rotate by -15 ~ +15 degree
        Left = np.random.uniform(-15, 15)
        rows, cols, color = image.shape
        M = cv2.getRotationMatrix2D((cols/2, rows/2), Left, 1)
        image_rotate = cv2.warpAffine(image, M, (cols, rows))
        images.append(image_rotate)

    print("--- reading image part-I DONE %s seconds ---" % (time.time() - start_time))
    images = np.array(images)

    print("--- reading image all DONE %s seconds ---" % (time.time() - start_time))


    #==== reading classes =====
    cls = []
    #clsFile = train_path.labels
    labels = [] 
    #clsFile = pd.read_csv(train_class_path, index_col=0)
    cls_tmp = train_path.labelss#clsFile.iloc[:,0].values
    for cur in cls_tmp:
        cls += [cur]*NUM_SAME_PIC
    cls = np.array(cls)

    print("--- reading classes DONE %s seconds ---" % (time.time() - start_time))

    print( "Is Label Number = Image Number?", cls.shape[0] == images.shape[0])

    #==== adding labels =====
    labels = []
    for i in cls:
        label = np.zeros(num_classes)
        label[i] = 1.0
        labels.append(label)
    labels = np.array(labels)


    #==== sampling validation out =====
    if isinstance(validation_size, float):
        validation_size = int(validation_size * (images.shape[0]/NUM_SAME_PIC))
    shuffle_idx_tmp = np.random.choice(int(images.shape[0]/NUM_SAME_PIC), validation_size, replace=False) 
    tmp = np.asarray(range(images.shape[0])) #9000
    shuffle_idx = np.reshape([tmp[i * NUM_SAME_PIC : (i+1) * NUM_SAME_PIC] for i in shuffle_idx_tmp], (3*len(shuffle_idx_tmp))) 
    # for [0, 7] generate [0, 1, 2, 21, 22, 23]
    not_shuffle_indx = [x for x in tmp if x not in shuffle_idx]

    validation_images = images[shuffle_idx]
    validation_labels = labels[shuffle_idx]
    validation_cls = cls[shuffle_idx]

    train_images = images[not_shuffle_indx]
    train_labels = labels[not_shuffle_indx]
    train_cls = cls[not_shuffle_indx]

    train_images, train_labels, train_cls = shuffle(train_images, train_labels, train_cls)

    print("--- all DONE %s seconds ---" % (time.time() - start_time))


    data_sets.train = DataSet(train_images, train_labels, train_cls)
    data_sets.valid = DataSet(validation_images, validation_labels, validation_cls)

    return data_sets

# %% [markdown]
# ### load data

# %%
data = read_train_sets(trainings, image_size, validation_size=validation_size)
print("Complete reading input data. Will Now print a snippet of it")
print("Number of files in Training-set:\t\t{}".format(len(data.train.cls)))
print("Number of files in Validation-set:\t{}".format(len(data.valid.cls)))
# Out:
# --- reading image part-I DONE 60.060017347335815 seconds ---
# --- reading image all DONE 117.33219718933105 seconds ---
# --- reading classes DONE 117.39096713066101 seconds ---
# Is Label Number = Image Number? True
# --- all DONE 346.1093943119049 seconds ---
# Complete reading input data. Will Now print a snippet of it
# Number of files in Training-set:		35010
# Number of files in Validation-set:	3888

# %% [markdown]
# ### Placeholders and Parameters

# %%
session = tf.Session()
x = tf.placeholder(tf.float32, shape=[None, image_size,image_size,num_channels], name='x')
y_true = tf.placeholder(tf.float32, shape=[None, num_classes], name='y_true') #labels
y_true_cls = tf.argmax(y_true, axis=1)

# %%
##Network graph params
filter_size_conv1 = 5#3 
num_filters_conv1 = 32

filter_size_conv2 = 5#3
num_filters_conv2 = 32

filter_size_conv3 = 5#3
num_filters_conv3 = 64
    
fc_layer_size = 128

# %% [markdown]
# ### CNN Layers Definition

# %%
def create_weights(shape):
    return tf.Variable(tf.truncated_normal(shape, stddev=0.05))

def create_biases(size):
    return tf.Variable(tf.constant(0.05, shape=[size]))

def create_convolutional_layer(input,
               num_input_channels, 
               conv_filter_size,        
               num_filters,
               layer_name):  
    
    ## We shall define the weights that will be trained using create_weights function.
    weights = create_weights(shape=[conv_filter_size, conv_filter_size, num_input_channels, num_filters])
    ## We create biases using the create_biases function. These are also trained.
    biases = create_biases(num_filters)

    ## Creating the convolutional layer
    layer = tf.nn.conv2d(input=input,
                     filter=weights,
                     strides=[1, 1, 1, 1],
                     padding='SAME', name = layer_name+'_conv2d')

    layer += biases

    ## We shall be using max-pooling.  
    layer = tf.nn.max_pool(value=layer,
                            ksize=[1, 2, 2, 1],
                            strides=[1, 2, 2, 1],
                            padding='SAME',name = layer_name+'_max_pool')
    ## Output of pooling is fed to Relu which is the activation function for us.
    layer = tf.nn.relu(layer, name = layer_name+'_relu')

    return layer

    

def create_flatten_layer(layer):
    #We know that the shape of the layer will be [batch_size img_size img_size num_channels] 
    # But let's get it from the previous layer.
    layer_shape = layer.get_shape()

    ## Number of features will be img_height * img_width* num_channels. But we shall calculate it in place of hard-coding it.
    num_features = layer_shape[1:4].num_elements()

    ## Now, we Flatten the layer so we shall have to reshape to num_features
    layer = tf.reshape(layer, [-1, num_features])

    return layer


def create_fc_layer(input, num_inputs, num_outputs, layer_name, use_relu=True,):
    
    #Let's define trainable weights and biases.
    weights = create_weights(shape=[num_inputs, num_outputs])
    biases = create_biases(num_outputs)

    # Fully connected layer takes input x and produces wx+b.Since, these are matrices, we use matmul function in Tensorflow
    layer = tf.matmul(input, weights) + biases
    if use_relu:
        layer = tf.nn.relu(layer, name = layer_name)

    return layer

def maxpool(x):
    """simple wrapper for tf.nn.max_pool with stride size 2"""
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

def norm(x): 
    """simple wrapper for tf.nn.lrn... See section 3.3 of Krizhevsky 2012 for details"""
    return tf.nn.lrn(x, depth_radius=5, bias=2, alpha=1e-4, beta=0.75)

# %%
layer_conv1 = create_convolutional_layer(input=x,
               num_input_channels=num_channels,
               conv_filter_size=filter_size_conv1,
               num_filters=num_filters_conv1,
               layer_name = 'layer_conv1')
# pool 1
#layer_pool1 = maxpool(layer_conv1)
# norm 1
#layer_norm1 = norm(layer_pool1)

#layer_conv2 = create_convolutional_layer(input=layer_norm1,
#               num_input_channels=num_filters_conv1,
#               conv_filter_size=filter_size_conv2,
#               num_filters=num_filters_conv2,
#               layer_name = 'layer_conv2')

# pool 2
#layer_pool2 = maxpool(layer_conv2)
# norm 2
#layer_norm2 = norm(layer_pool2)

layer_conv2 = create_convolutional_layer(input=layer_conv1,
               num_input_channels=num_filters_conv1,
               conv_filter_size=filter_size_conv2,
               num_filters=num_filters_conv2,
               layer_name = 'layer_conv2')
          
layer_flat = create_flatten_layer(layer_conv2)

layer_fc1 = create_fc_layer(input=layer_flat,
                     num_inputs=layer_flat.get_shape()[1:4].num_elements(),
                     num_outputs=fc_layer_size,
                     layer_name = 'layer_fc1',
                     use_relu = True)

layer_fc2 = create_fc_layer(input=layer_fc1,
                     num_inputs=fc_layer_size,
                     num_outputs=num_classes,
                     layer_name = 'layer_fc2',
                     use_relu = False) 

y_pred = tf.nn.softmax(layer_fc2,name='y_pred')

y_pred_cls = tf.argmax(y_pred, axis=1)


cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=layer_fc2,
                                                    labels=y_true)
cost = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)
correct_prediction = tf.equal(y_pred_cls, y_true_cls)
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %% [markdown]
# ### Training Function and Saving to Tensorboard

# %%
def train(num_iteration):
    record_best_acc = 0
    record_best_val_acc = 0
    
    training_summary = tf.summary.scalar("training_accuracy", accuracy)
    validation_summary = tf.summary.scalar("validation_accuracy", accuracy)
    validation_cost = tf.summary.scalar("validation_cost", cost)
    
    graph_location = tempfile.mkdtemp()
    print('Saving graph to: %s' % graph_location)
    train_writer = tf.summary.FileWriter(graph_location)
    train_writer.add_graph(tf.get_default_graph())
    
    writer = tf.summary.FileWriter(graph_location, graph=tf.get_default_graph())
    
    for i in range(num_iteration):

        x_batch, y_true_batch, cls_batch = data.train.next_batch(batch_size)
        x_valid_batch, y_valid_batch, valid_cls_batch = data.valid.next_batch(batch_size)

        
        feed_dict_tr = {x: x_batch,
                           y_true: y_true_batch}
        feed_dict_val = {x: x_valid_batch,
                              y_true: y_valid_batch}

        session.run(optimizer, feed_dict=feed_dict_tr)
        
        
        if i % 100 == 0: 
            epoch = int(i / 100)
            
            #tensorboard
            acc,train_summ = session.run([accuracy,training_summary], feed_dict=feed_dict_tr)
            writer.add_summary(train_summ, i)
            val_acc,val_loss, valid_summ,val_cost = session.run([accuracy, cost, validation_summary,validation_cost], feed_dict=feed_dict_val)
            writer.add_summary(valid_summ, i)
            writer.add_summary(val_cost, i)
            
            # print output
            #print(val_loss)
            msg = "Training Epoch {0} --- Training Accuracy: {1:>6.1%}, Validation Accuracy: {2:>6.1%},  Validation Loss: {3:.3f}"
            print(msg.format(epoch + 1, acc, val_acc, val_loss))
            
            
            if (val_acc > record_best_val_acc) and (acc > record_best_acc) :
                record_best_acc = acc
                record_best_val_acc = val_acc
                
                saver.save(session, 'where_are_my_puppies_test00001')

# %% [markdown]
# ### Training Model

# %%
session.run(tf.global_variables_initializer()) 
saver = tf.train.Saver()
train(num_iteration=5000)
#train(num_iteration=10000)

sess.close()
# Out:
# Saving graph to: /var/folders/2q/v3sw8d6n2h50by9dfyj787mw0000gn/T/tmp0jgr8v16
# Training Epoch 1 --- Training Accuracy:   1.0%, Validation Accuracy:   0.6%,  Validation Loss: 4.867
# Training Epoch 2 --- Training Accuracy:   1.4%, Validation Accuracy:   0.6%,  Validation Loss: 4.747

# %%
sess.close()
